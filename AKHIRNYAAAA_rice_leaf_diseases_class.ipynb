# %% [markdown]
# ###Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Penyakit_Padi/dataset
# %ls
# Out:
# /content/drive/MyDrive/Penyakit_Padi/dataset
# blight_smut_spot/  logs/                   split_2_baru/  split_2_tomat/
# dataset_tomat/     ricenet_2_split_v3.png  split_2_part/  split_3_part/

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Splitting Data

# %%
# !pip install split-folders # instalasi library splitfolders

import splitfolders # inisialisasi splitfolders

src_dir = '/content/drive/MyDrive/Penyakit_Padi/dataset/blight_smut_spot'
dest_dir = '/content/drive/MyDrive/Penyakit_Padi/dataset/split_3_part'

splitfolders.ratio(src_dir, output=dest_dir, seed=42, ratio=(.9, .1)) # pembagian data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 120 files [00:56,  2.11 files/s]

# %% [markdown]
# #### Import Library

# %%
import os # manipulasi direktori data
import cv2 # manipulasi citra
import numpy as np # manipulasi matriks
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import callbacks
from tensorflow.keras.models import Sequential

import tensorflow.keras as tfkr
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %% [markdown]
# #### Show Data

# %%
base_dir = '/content/drive/MyDrive/Penyakit_Padi/dataset'

splitted_dir = os.path.join(base_dir, 'split_3_part')

train_dir = os.path.join(splitted_dir, 'train')
blight_train_dir = os.path.join(train_dir, 'Bacterial leaf blight')
spot_train_dir = os.path.join(train_dir, 'Brown spot')
smut_train_dir = os.path.join(train_dir, 'Leaf smut')

val_dir = os.path.join(splitted_dir, 'val')
blight_val_dir = os.path.join(val_dir, 'Bacterial leaf blight')
spot_val_dir = os.path.join(val_dir, 'Brown spot')
smut_val_dir = os.path.join(val_dir, 'Leaf smut')

# %%
print("Total Train Blight:", len(os.listdir(blight_train_dir)))
print("Total Train Spot:", len(os.listdir(spot_train_dir)))
print("Total Train Smut:", len(os.listdir(smut_train_dir)))
print('-'*30)
print("Total Val Blight:", len(os.listdir(blight_val_dir)))
print("Total Val Spot:", len(os.listdir(spot_val_dir)))
print("Total Val Smut:", len(os.listdir(smut_val_dir)))
# Out:
# Total Train Blight: 36
# Total Train Spot: 36
# Total Train Smut: 36
# ------------------------------
# Total Val Blight: 4
# Total Val Spot: 4
# Total Val Smut: 4

# %%
data_dir = os.path.join(base_dir, 'blight_smut_spot')

blight_dir = os.path.join(data_dir, 'Bacterial leaf blight')
spot_dir = os.path.join(data_dir, 'Brown spot')
smut_dir = os.path.join(data_dir, 'Leaf smut')

# %%
import matplotlib.pyplot as plt
data_per_class = {
    'Bacterial leaf blight': len(os.listdir(blight_dir)),
    'Brown spot': len(os.listdir(spot_dir)),
    'Leaf smut': len(os.listdir(smut_dir))
    }

plt.bar(data_per_class.keys(), data_per_class.values());
plt.title("Jumlah Data setiap Kelas");
plt.ylabel('# Gambar');

# %%
blight_img_file = os.path.join(blight_train_dir, os.listdir(blight_train_dir)[0])
spot_img_file = os.path.join(spot_train_dir, os.listdir(spot_train_dir)[0])
smut_img_file = os.path.join(smut_train_dir, os.listdir(smut_train_dir)[0])

img_file = [blight_img_file, spot_img_file, smut_img_file]
img_file
# Out:
# ['/content/drive/MyDrive/Penyakit_Padi/dataset/split_3_part/train/Bacterial leaf blight/DSC_0377.JPG',
#  '/content/drive/MyDrive/Penyakit_Padi/dataset/split_3_part/train/Brown spot/DSC_0111.jpg',
#  '/content/drive/MyDrive/Penyakit_Padi/dataset/split_3_part/train/Leaf smut/DSC_0317.JPG']

# %%
import matplotlib.pyplot as plt

nrows = 1
ncols = 3

fig = plt.gcf()
fig.set_size_inches(ncols * 3, nrows * 3)

for i, img_path in enumerate(img_file):
    plt.subplot(nrows, ncols, i + 1)

    img = cv2.imread(img_path)
    img = cv2.resize(img, (180,180))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    true_label = img_path.split(os.path.sep)[-2]

    plt.grid(False)
    plt.axis(False)
    plt.title(true_label, fontdict={'fontsize': 14})
    plt.imshow(img)

plt.show()

# %% [markdown]
# #### Augmentasi

# %%
aug = tfkr.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tfkr.applications.resnet.preprocess_input,
    rotation_range=30,
    zoom_range=0.4,
    horizontal_flip=True
    )

train_gen = aug.flow_from_directory(
    train_dir,
    batch_size=64,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    target_size=(224, 224)
    )

val_gen = aug.flow_from_directory(
    val_dir,
    batch_size=64,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    target_size=(224, 224)
    )
# Out:
# Found 108 images belonging to 3 classes.
# Found 12 images belonging to 3 classes.

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### ResNet101 base

# %%
model_n_weight_dir = '/content/drive/MyDrive/Colab_Notebooks/ResNet101_weight'
wp = model_n_weight_dir + '/(3)resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
ResNet101_base = tfkr.applications.resnet.ResNet101(
    include_top=False,
    # pooling='avg',
    weights=wp,
    input_tensor=None,
    input_shape=(224, 224, 3)
    )

for layer in ResNet101_base.layers:
  layer.trainable = False

# %% [markdown]
# #### Base adding

# %%
model = tfkr.models.Sequential()

model.add(ResNet101_base)

model.add(tfkr.layers.Flatten())

model.add(tfkr.layers.Dense(128, activation='relu'))
model.add(tfkr.layers.BatchNormalization())
model.add(tfkr.layers.Dropout(0.3))

model.add(tfkr.layers.Dense(32, activation='relu'))
model.add(tfkr.layers.BatchNormalization())
model.add(tfkr.layers.Dropout(0.1))

model.add(tfkr.layers.Dense(3, activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 7, 7, 2048)        42658176
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 55,508,227
# Trainable params: 12,849,731
# Non-trainable params: 42,658,496
# _________________________________________________________________
# None

# %%
# model = tfkr.models.Sequential()

# model.add(ResNet101_base)

# model.add(tfkr.layers.Flatten())

# model.add(tfkr.layers.Dense(512, activation='relu'))
# model.add(tfkr.layers.BatchNormalization())
# model.add(tfkr.layers.Dropout(0.7))
# model.add(tfkr.layers.Dropout(0.7))

# model.add(tfkr.layers.Dense(64, activation='relu'))
# model.add(tfkr.layers.BatchNormalization())
# model.add(tfkr.layers.Dropout(0.3))
# model.add(tfkr.layers.Dropout(0.3))

# model.add(tfkr.layers.Dense(3, activation='softmax'))

# print(model.summary())

# %% [markdown]
# #### Model architecture viz

# %%
# from tensorflow.keras.utils import plot_model

# plot_model(ResNet101_base,
#            to_file='ricenet_2_split_v3.png',
#            show_shapes=True,
#         #    show_layer_names=False
#            )

# %% [markdown]
# #### Compiling

# %%
model.compile(
    optimizer=tfkr.optimizers.Adam(learning_rate=0.0001),
    loss='mean_absolute_error',
    # loss='categorical_crossentropy',
    metrics =['accuracy']
    )

# %% [markdown]
# #### Callback

# %%
target_dir = '/content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class'
directory_to_save_best_model_file = target_dir + '/ricenet_best_cheskpoint_v4.h5'
best_model = ModelCheckpoint(directory_to_save_best_model_file,
                             monitor='val_accuracy',
                             verbose = 1,
                             save_best_only = True
                             )

# %% [markdown]
# #### Fitting

# %%
H = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=100,
    callbacks=best_model,
    verbose=1
    )
# Out:
# Epoch 1/100
# 2/2 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.4537
# Epoch 1: val_accuracy improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class/ricenet_best_cheskpoint_v4.h5
# 2/2 [==============================] - 28s 8s/step - loss: 0.3869 - accuracy: 0.4537 - val_loss: 0.2209 - val_accuracy: 0.6667
# Epoch 2/100
# 2/2 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.7315
# Epoch 2: val_accuracy did not improve from 0.66667
# 2/2 [==============================] - 5s 2s/step - loss: 0.2416 - accuracy: 0.7315 - val_loss: 0.2222 - val_accuracy: 0.6667
# Epoch 3/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.8519
# Epoch 3: val_accuracy improved from 0.66667 to 0.83333, saving model to /content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class/ricenet_best_cheskpoint_v4.h5
# 2/2 [==============================] - 7s 5s/step - loss: 0.1703 - accuracy: 0.8519 - val_loss: 0.1527 - val_accuracy: 0.8333
# Epoch 4/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.8981
# Epoch 4: val_accuracy improved from 0.83333 to 0.91667, saving model to /content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class/ricenet_best_cheskpoint_v4.h5
# 2/2 [==============================] - 7s 5s/step - loss: 0.1279 - accuracy: 0.8981 - val_loss: 0.0962 - val_accuracy: 0.9167
# Epoch 5/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.8704
# Epoch 5: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 5s 2s/step - loss: 0.1320 - accuracy: 0.8704 - val_loss: 0.1228 - val_accuracy: 0.8333
# Epoch 6/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9259
# Epoch 6: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 6s 4s/step - loss: 0.0912 - accuracy: 0.9259 - val_loss: 0.0661 - val_accuracy: 0.9167
# Epoch 7/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9630
# Epoch 7: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 5s 2s/step - loss: 0.0760 - accuracy: 0.9630 - val_loss: 0.1027 - val_accuracy: 0.8333
# Epoch 8/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9444
# Epoch 8: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 5s 3s/step - loss: 0.0849 - accuracy: 0.9444 - val_loss: 0.1044 - val_accuracy: 0.8333
# Epoch 9/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9259
# Epoch 9: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 5s 2s/step - loss: 0.0851 - accuracy: 0.9259 - val_loss: 0.0660 - val_accuracy: 0.9167
# Epoch 10/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9537
# Epoch 10: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 5s 2s/step - loss: 0.0668 - accuracy: 0.9537 - val_loss: 0.0999 - val_accuracy: 0.8333
# Epoch 11/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9630
# Epoch 11: val_accuracy did not improve from 0.91667
# 2/2 [==============================] - 6s 4s/step - loss: 0.0598 - accuracy: 0.9630 - val_loss: 0.0637 - val_accuracy: 0.9167
# Epoch 12/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9537
# Epoch 12: val_accuracy improved from 0.91667 to 1.00000, saving model to /content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class/ricenet_best_cheskpoint_v4.h5
# 2/2 [==============================] - 9s 7s/step - loss: 0.0635 - accuracy: 0.9537 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 13/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9815
# Epoch 13: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0535 - accuracy: 0.9815 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 14/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9815
# Epoch 14: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 6s 4s/step - loss: 0.0505 - accuracy: 0.9815 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 15/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9537
# Epoch 15: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0578 - accuracy: 0.9537 - val_loss: 0.0507 - val_accuracy: 0.9167
# Epoch 16/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9815
# Epoch 16: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0520 - accuracy: 0.9815 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 17/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9722
# Epoch 17: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0540 - accuracy: 0.9722 - val_loss: 0.0554 - val_accuracy: 0.9167
# Epoch 18/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9907
# Epoch 18: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0338 - accuracy: 0.9907 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 19/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9815
# Epoch 19: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0457 - accuracy: 0.9815 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 20/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9907
# Epoch 20: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0351 - accuracy: 0.9907 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 21/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9907
# Epoch 21: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0335 - accuracy: 0.9907 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 22/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9722
# Epoch 22: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0445 - accuracy: 0.9722 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 23/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9815
# Epoch 23: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0481 - accuracy: 0.9815 - val_loss: 0.0245 - val_accuracy: 1.0000
# Epoch 24/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9907
# Epoch 24: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0416 - accuracy: 0.9907 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 25/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 26/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9907
# Epoch 26: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0348 - accuracy: 0.9907 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 27/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 28/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9907
# Epoch 28: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0258 - accuracy: 0.9907 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 29/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 30/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9167
# Epoch 31/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 32/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 33/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.9167
# Epoch 34/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 35/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 36/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.8333
# Epoch 37/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 7s 4s/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 38/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9167
# Epoch 39/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 40/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9907
# Epoch 40: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0246 - accuracy: 0.9907 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 41/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9167
# Epoch 42/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 0.9167
# Epoch 43/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 44/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 45/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9167
# Epoch 46/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9167
# Epoch 47/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 48/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9167
# Epoch 49/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 50/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9167
# Epoch 51/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 52/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 53/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 54/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 55/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 56/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 0.9167
# Epoch 57/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 58/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9167
# Epoch 59/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 60/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 61/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 62/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 63/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9907
# Epoch 63: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0164 - accuracy: 0.9907 - val_loss: 0.0665 - val_accuracy: 0.9167
# Epoch 64/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9167
# Epoch 65/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9907
# Epoch 70: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0198 - accuracy: 0.9907 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9167
# Epoch 76/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9167
# Epoch 79/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9167
# Epoch 81/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9167
# Epoch 82/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 6s 4s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 2s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9167
# Epoch 99/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 1.00000
# 2/2 [==============================] - 5s 3s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9167

# %% [markdown]
# #### Save Model

# %%
import json

target_dir = '/content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class'

# simpan history model
history_dict = H.history
json.dump(history_dict, open(target_dir + '/ricenet_split_2_v4.json', 'w'))

# simpan model dan weight-nya
model.save(target_dir + '/ricenet_split_2_v4.h5')

# %% [markdown]
# #### Load Model Weight and History

# %%
from keras.models import load_model
import json

target_dir = '/content/drive/MyDrive/Colab_Notebooks/Andre_rice_leaf_diseases_class'
model = load_model(target_dir + '/ricenet_best_cheskpoint_v4.h5')
history = json.load(open(target_dir + '/ricenet_split_2_v4.json', 'r'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 7, 7, 2048)        42658176
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 55,508,227
# Trainable params: 12,849,731
# Non-trainable params: 42,658,496
# _________________________________________________________________

# %% [markdown]
# ### Evaluation

# %%
loss, acc = model.evaluate(val_gen)
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.0291 - accuracy: 1.0000

# %% [markdown]
# #### Acc and Loss Plot

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history[met])
    ax[i].plot(history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# #### Classification Report

# %%
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import preprocess_input
from tensorflow.keras.applications.resnet import preprocess_input

val_aug = ImageDataGenerator(preprocessing_function=preprocess_input)

val_gen = val_aug.flow_from_directory(val_dir,
                                      batch_size=64,
                                      class_mode=None,
                                      shuffle=False,
                                      target_size=(224, 224))
# Out:
# Found 12 images belonging to 3 classes.

# %%
from sklearn.metrics import classification_report

y_true = val_gen.classes

pred_result = model.predict(val_gen)
y_pred = np.argmax(pred_result, axis=-1)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

labels = val_gen.class_indices
labels = [label.replace(" ", "\n").title() for label in labels]

cmatrix_result = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5,5))
ax = plt.subplot()

data = np.asarray(cmatrix_result).reshape(3,3)

sns.set(font_scale=1.25)
sns.heatmap(data,
            annot=True,
            ax=ax,
            cmap="Blues",
            square=True,
            linewidths=.3,
            xticklabels=labels,
            yticklabels=labels
            )

ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

plt.yticks(rotation=0)
plt.title('Confusion Matrix Test')
plt.show()

# %% [markdown]
# #### Image Prediction

# %%
def pred_img(img_path):
    img = load_img(img_path, target_size=(224,224))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    pred_result = model.predict(img)
    pred_value = np.argmax(pred_result[0])
    confidence_percent = np.max(pred_result[0]) * 100
    pred_label = 'Bacterial leaf blight' if pred_value == 0 else 'Brown spot' if pred_value == 1 else 'Leaf smut'
    return pred_label, confidence_percent

# %%
import os
blight_dir = [os.path.join(blight_val_dir, fname) for fname in os.listdir(blight_val_dir)[:3]]
spot_dir = [os.path.join(spot_val_dir, fname) for fname in os.listdir(spot_val_dir)[:3]]
smut_dir = [os.path.join(smut_val_dir, fname) for fname in os.listdir(smut_val_dir)[:3]]

rice_diseases = blight_dir + spot_dir + smut_dir

# %%
import cv2
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

nrows = 3
ncols = 3

fig = plt.gcf()
fig.set_size_inches(ncols * 5, nrows * 5)

for i, img_path in enumerate(rice_diseases):
    plt.subplot(nrows, ncols, i + 1)
    plt.subplots_adjust(hspace=1.5)

    img = cv2.imread(img_path)
    img = cv2.resize(img, (224,224))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    true_label = img_path.split(os.path.sep)[-2]
    pred_result = pred_img(img_path)
    pred_label = pred_result[0]
    confidence_percent = pred_result[1]
    # pred_time = pred_result[2]

    plt.title(f"True Label: {true_label}\nPred Label: {pred_label}\nAkurasi: {confidence_percent:.2f}", y=1.15)
    plt.imshow(img)

plt.show()
